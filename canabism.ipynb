# %% [markdown]
# ### Imports

# %%
import pandas as pd

# %% [markdown]
# ### DataFrame from csv file

# %%
df = pd.read_csv("CanabisBenefits.csv", index_col="health condition")

df.head()
# Out:
#                                                              alternate name  \
# health condition
# ADD/ADHD                                                                NaN
# Adolescence                                                             NaN
# AIDS-related weight loss                                                NaN
# ALS                       Amyotrophic Lateral Sclerosis, Lou Gehrig's Di...
# Alzheimer’s                                                             NaN
#
#                          health condition.1  \
# health condition
# ADD/ADHD                      mental health
# Adolescence                    neurological
# AIDS-related weight loss      immune system
# ALS                            neurological
# Alzheimer’s                    neurological
#
#                           evidence score 0 = harmful \n1 = no / insufficient evidence\n6 = strong   \
# health condition
# ADD/ADHD                                                                  1
# ...

# %% [markdown]
# ### Checking for duplicate

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [alternate name, health condition.1, evidence score 0 = harmful
# 1 = no / insufficient evidence
# 6 = strong , popular interest, Number of citations on Google Scholar (2000-2017) search format: condition+cannabis, CBD, simple English notes, notes, link, other International review board or metastudy, individual study, main study source name, other sources]
# Index: []

# %% [markdown]
# ### Removing Columns

# %% [markdown]
# Checking for Null Values

# %%
non_nulls_df = df.dropna()
non_nulls_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 13 columns):
#  #   Column                                                                               Non-Null Count  Dtype
# ---  ------                                                                               --------------  -----
#  0   alternate name                                                                       0 non-null      object
#  1   health condition.1                                                                   0 non-null      object
#  2   evidence score 0 = harmful
# 1 = no / insufficient evidence
# 6 = strong                0 non-null      int64
#  3   popular interest                                                                     0 non-null      int64
#  4   Number of citations on Google Scholar (2000-2017) search format: condition+cannabis  0 non-null      int64
# ...
